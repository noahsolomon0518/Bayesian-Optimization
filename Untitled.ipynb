# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor as GPR
from sklearn.gaussian_process.kernels import RBF

#Create perfect line of data
def createData(w,b):
    x = [i for i in range(20)]
    y = [w*xi+b for xi in x]
    plt.scatter(x,y)
    return (x,y)
x,y = createData(2,5)

# %%
def calculateWeights(x,y, iterations):
    domain = [(w,b) for w in range(20) for b in range(20)]
    params = []
    accuracies = []
    curParams = (0,0)
    for i in range(iterations):
        NMSE = negativeMSE(curParams[0],curParams[1], x,y)
        params.append([curParams[0],curParams[1]])
        accuracies.append(NMSE)
        gprModel = GPR(kernel=RBF(),random_state=0).fit(params, accuracies)
        predNMSE, std = gprModel.predict(domain,return_std = True)
        print("weights: ", curParams, "NMSE: ",NMSE )
        curParams = MEI(predNMSE, std, domain)
    print("Final weights are: ", curParams)
    return (params,accuracies)
     
        
        
#fit linear model with w and b then evaluates using negative mse
def negativeMSE(w, b, xTrain, yTrain):
    xTrain = np.array(xTrain)
    yTrain = np.array(yTrain)
    yPred = w*xTrain+b
    SSE = sum((np.array(yPred)-np.array(yTrain))**2)
    NMSE = -SSE/len(yPred)
    return NMSE



def MEI(predNMSE,std, domain):
    ind = np.argmax(np.array(predNMSE)+np.array(std))
    return np.array(domain)[ind]

# %%
params,accuracies = calculateWeights(x,y,200)
# Out:
# weights:  (0, 0) NMSE:  -709.0
# weights:  [ 0 10] NMSE:  -329.0
# weights:  [ 3 19] NMSE:  -585.5
# weights:  [8 5] NMSE:  -4446.0
# weights:  [12 14] NMSE:  -14141.0
# weights:  [17  0] NMSE:  -26387.5
# weights:  [19 19] NMSE:  -40409.5
# weights:  [19  9] NMSE:  -36999.5
# weights:  [ 6 11] NMSE:  -2468.0
# weights:  [0 5] NMSE:  -494.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [11  0] NMSE:  -9173.5
# weights:  [ 9 19] NMSE:  -8109.5
# weights:  [4 0] NMSE:  -329.0
# weights:  [ 0 17] NMSE:  -182.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [ 0 19] NMSE:  -158.0
# weights:  [13  8] NMSE:  -15579.5
# weights:  [17 14] NMSE:  -30433.5
# weights:  [14 19] NMSE:  -21172.0
# weights:  [ 4 15] NMSE:  -974.0
# weights:  [ 2 14] NMSE:  -81.0
# weights:  [ 1 17] NMSE:  -39.5
# weights:  [ 1 17] NMSE:  -39.5
# weights:  [4 7] NMSE:  -574.0
# weights:  [2 9] NMSE:  -16.0
# weights:  [19  4] NMSE:  -35369.5
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [2 8] NMSE:  -9.0
# weights:  [ 0 14] NMSE:  -233.0
# weights:  [3 3] NMSE:  -89.5
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# weights:  [2 4] NMSE:  -1.0
# Final weights are:  [2 4]

# %%
from mpl_toolkits.mplot3d import Axes3D
params = np.array(params)
accuracies = np.array(accuracies)


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(params[:,0],params[:,1],accuracies)
ax.scatter(2,5,0)
ax.set_xlabel('w', c = 'b')
ax.set_ylabel('b', c = 'b')
ax.set_zlabel('NMSE', c = 'b')
ax.set_title('NMSE with respect to hyperparameters')
# Out:
# Text(0.5, 0.92, 'NMSE with respect to hyperparameters')
